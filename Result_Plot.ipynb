# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusrat-Richi/MLmodel/blob/main/Result_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Syntactic Complexity")
x = np.array(["ChatGPT", "Gemini", "DeepSeek", "NotebookLM","Grok"])
y = np.array([2.9, 4.82, 1.92, 2.61, 1.67])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Semantic Richness")
x = np.array(["ChatGPT", "Gemini", "DeepSeek", "NotebookLM","Grok"])
y = np.array([26.52, 25.76, 23.12, 25.14, 22.22])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("NER Count")
x = np.array(["ChatGPT", "Gemini", "DeepSeek", "NotebookLM","Grok"])
y = np.array([35.09, 14.06, 39.8, 34.97, 62.71])

plt.bar(x,y)
plt.show()
